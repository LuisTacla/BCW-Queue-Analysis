# %%
import pandas as pd
import os
from datetime import datetime

diretorio_origem = "ride-rawdata/2024"
diretorio_destino = "ride-data"

tabela_horarios = pd.read_excel("bcw-operation-calendar.xlsx")
tabela_horarios["date"] = pd.to_datetime(tabela_horarios["date"]).dt.date

# Lista todos os arquivos CSV na pasta de origem
arquivos = os.listdir(diretorio_origem)

# Lista para armazenar os DataFrames tratados
dataframes_tratados = []

for arquivo in arquivos:
    if arquivo.endswith(".csv"):
        caminho_arquivo_origem = os.path.join(diretorio_origem, arquivo)
        df = pd.read_csv(caminho_arquivo_origem)
        
        # Renomear as colunas
        df.rename(columns={"Ride": "ride_name", "Date/Time": "data_hora", "Wait Time": "wait_time"}, inplace=True)
        
        # Separar a coluna 'data_hora' em colunas de 'date' e 'time'
        df["date"] = pd.to_datetime(df["data_hora"]).dt.date
        df["time"] = pd.to_datetime(df["data_hora"]).dt.time
        
        # Inicializar uma lista para armazenar as linhas que atendem aos critérios
        linhas_mantidas = []
        
        for indice, linha in df.iterrows():            
            # Encontrar os horários de abertura e fechamento para o dia atual
            horarios_do_dia = tabela_horarios[tabela_horarios["date"] == linha["date"]]
            
            if not horarios_do_dia.empty:
                abertura = horarios_do_dia["park_opening_time"].iloc[0]
                fechamento = horarios_do_dia["park_closing_time"].iloc[0]
                parque_aberto = horarios_do_dia["park_open"].iloc[0]
                
                if parque_aberto:
                    if abertura is not None and fechamento is not None:
                        # Verificar se a hora está dentro do intervalo de abertura e fechamento
                        if abertura <= linha["time"] <= fechamento:
                            linhas_mantidas.append(indice)

        # Verificar se há linhas mantidas antes de prosseguir
        if len(linhas_mantidas) > 0:
            # Criar um novo DataFrame com as linhas que atendem aos critérios
            df_filtrado = df.loc[linhas_mantidas]
            
            # Criar um novo DataFrame com as colunas desejadas da tabela_horarios
            colunas_desejadas = ["date", "day_of_the_week", "sale", "holiday", "holiday_season", "season",
                                 "HotWheels 1130", "HotWheels 1330", "HotWheels 1530", "HotWheels 1730", "Acqua 1400",
                                 "Acqua 1500", "Madagascar 1500", "Madagascar 1600", "Madagascar 1700", "Sonho 1800",
                                 "Excalibur 1200", "Excalibur 1430", "Excalibur 1700"]
            
            # Filtrar as colunas desejadas da tabela_horarios correspondentes à data do arquivo atual
            colunas_desejadas_df = tabela_horarios[tabela_horarios["date"] == df_filtrado["date"].iloc[0]][colunas_desejadas]
            
            # Mesclar o dataframe filtrado com as colunas desejadas
            df_filtrado = pd.merge(df_filtrado, colunas_desejadas_df, on="date", how="left")
            
            # Adicionar o DataFrame tratado à lista de DataFrames tratados
            dataframes_tratados.append(df_filtrado)
            
            print("TERMINADO O ARQUIVO " + caminho_arquivo_origem)

# Concatenar todos os DataFrames tratados em um único DataFrame
df_final = pd.concat(dataframes_tratados, ignore_index=True)

# Salvar o DataFrame final em um único arquivo
caminho_arquivo_destino = os.path.join(diretorio_destino, "dados_tratados_2024.csv")
df_final.to_csv(caminho_arquivo_destino, index=False)

print("TERMINADO O PROCESSAMENTO DE TODOS OS ARQUIVOS")
# Out:
# TERMINADO O ARQUIVO ride-rawdata/2024\download_autopistabatebate_feb_8130_2024_04_11_22_21_41.csv
# TERMINADO O ARQUIVO ride-rawdata/2024\download_autopistabatebate_jan_8130_2024_04_11_22_21_29.csv
# TERMINADO O ARQUIVO ride-rawdata/2024\download_autopistabatebate_mar_8130_2024_04_11_22_21_45.csv
# TERMINADO O ARQUIVO ride-rawdata/2024\download_babyelefante_feb_8130_2024_04_11_22_21_58.csv
# TERMINADO O ARQUIVO ride-rawdata/2024\download_babyelefante_jan_8130_2024_04_11_22_21_52.csv
# TERMINADO O ARQUIVO ride-rawdata/2024\download_babyelefante_mar_8130_2024_04_11_22_22_03.csv
# TERMINADO O ARQUIVO ride-rawdata/2024\download_barcopirata_feb_8130_2024_04_11_22_22_19.csv
# TERMINADO O ARQUIVO ride-rawdata/2024\download_barcopirata_jan_8130_2024_04_11_22_22_12.csv
# TERMINADO O ARQUIVO ride-rawdata/2024\download_barcopirata_mar_8130_2024_04_11_22_22_23.csv
# TERMINADO O ARQUIVO ride-rawdata/2024\download_betinhocarrerod_feb_8130_2024_04_11_22_22_38.csv
# TERMINADO O ARQUIVO ride-rawdata/2024\download_betinhocarrerod_jan_8130_2024_04_11_22_22_31.csv
# TERMINADO O ARQUIVO ride-rawdata/2024\download_betinhocarrerod_mar_8130_2024_04_11_22_22_41.csv
# TERMINADO O ARQUIVO ride-rawdata/2024\download_bigtower_feb_8130_2024_04_11_22_22_52.csv
# TERMINADO O ARQUIVO ride-rawdata/2024\download_bigtower_jan_8130_2024_04_11_22_22_48.csv
# TERMINADO O ARQUIVO ride-rawdata/2024\download_bigtower_mar_8130_2024_04_11_22_22_56.csv
# TERMINADO O ARQUIVO ride-rawdata/2024\download_carrosselveneziano_feb_8130_2024_04_11_22_23_08.csv
# TERMINADO O ARQUIVO ride-rawdata/2024\download_carrosselveneziano_jan_8130_2024_04_11_22_23_03.csv
# TERMINADO O ARQUIVO ride-rawdata/2024\download_carrosselveneziano_mar_8130_2024_04_11_22_23_11.csv
# TERMINADO O ARQUIVO ride-rawdata/2024\download_ferroviadinomagic_feb_8130_2024_04_11_22_23_21.csv
# TERMINADO O ARQUIVO ride-rawdata/2024\download_ferroviadinomagic_jan_8130_2024_04_11_22_23_18.csv
# TERMINADO O ARQUIVO ride-rawdata/2024\download_ferroviadinomagic_mar_8130_2024_04_11_22_23_25.csv
# TERMINADO O ARQUIVO ride-rawdata/2024\download_firewhip_feb_8130_2024_04_11_22_23_34.csv
# TERMINADO O ARQUIVO ride-rawdata/2024\download_firewhip_jan_8130_2024_04_11_22_23_30.csv
# TERMINADO O ARQUIVO ride-rawdata/2024\download_firewhip_mar_8130_2024_04_11_22_23_37.csv
# TERMINADO O ARQUIVO ride-rawdata/2024\download_madagascarcrazyriveradventure_feb_8130_2024_04_11_22_23_52.csv
# TERMINADO O ARQUIVO ride-rawdata/2024\download_madagascarcrazyriveradventure_jan_8130_2024_04_11_22_23_49.csv
# TERMINADO O ARQUIVO ride-rawdata/2024\download_madagascarcrazyriveradventure_mar_8130_2024_04_11_22_23_56.csv
# TERMINADO O ARQUIVO ride-rawdata/2024\download_montanharussadumdum_feb_8130_2024_04_11_22_24_13.csv
# TERMINADO O ARQUIVO ride-rawdata/2024\download_montanharussadumdum_jan_8130_2024_04_11_22_24_09.csv
# TERMINADO O ARQUIVO ride-rawdata/2024\download_montanharussadumdum_mar_8130_2024_04_11_22_24_16.csv
# TERMINADO O ARQUIVO ride-rawdata/2024\download_pedalinho_feb_8130_2024_04_11_22_24_26.csv
# TERMINADO O ARQUIVO ride-rawdata/2024\download_pedalinho_jan_8130_2024_04_11_22_24_23.csv
# TERMINADO O ARQUIVO ride-rawdata/2024\download_pedalinho_mar_8130_2024_04_11_22_24_29.csv
# TERMINADO O ARQUIVO ride-rawdata/2024\download_raskapuska_feb_8130_2024_04_11_22_24_39.csv
# TERMINADO O ARQUIVO ride-rawdata/2024\download_raskapuska_jan_8130_2024_04_11_22_24_35.csv
# TERMINADO O ARQUIVO ride-rawdata/2024\download_raskapuska_mar_8130_2024_04_11_22_24_42.csv
# TERMINADO O ARQUIVO ride-rawdata/2024\download_rebulico_feb_8130_2024_04_11_22_24_50.csv
# TERMINADO O ARQUIVO ride-rawdata/2024\download_rebulico_jan_8130_2024_04_11_22_24_47.csv
# TERMINADO O ARQUIVO ride-rawdata/2024\download_rebulico_mar_8130_2024_04_11_22_24_53.csv
# TERMINADO O ARQUIVO ride-rawdata/2024\download_rodagigante_feb_8130_2024_04_11_22_25_03.csv
# TERMINADO O ARQUIVO ride-rawdata/2024\download_rodagigante_jan_8130_2024_04_11_22_25_00.csv
# TERMINADO O ARQUIVO ride-rawdata/2024\download_rodagigante_mar_8130_2024_04_11_22_25_10.csv
# TERMINADO O ARQUIVO ride-rawdata/2024\download_spinblast_feb_8130_2024_04_11_22_25_22.csv
# TERMINADO O ARQUIVO ride-rawdata/2024\download_spinblast_jan_8130_2024_04_11_22_25_17.csv
# TERMINADO O ARQUIVO ride-rawdata/2024\download_spinblast_mar_8130_2024_04_11_22_25_25.csv
# TERMINADO O ARQUIVO ride-rawdata/2024\download_starmountain_feb_8130_2024_04_11_22_25_34.csv
# TERMINADO O ARQUIVO ride-rawdata/2024\download_starmountain_jan_8130_2024_04_11_22_25_30.csv
# TERMINADO O ARQUIVO ride-rawdata/2024\download_starmountain_mar_8130_2024_04_11_22_25_37.csv
# TERMINADO O ARQUIVO ride-rawdata/2024\download_supersoakersplash_feb_8130_2024_04_11_22_25_46.csv
# TERMINADO O ARQUIVO ride-rawdata/2024\download_supersoakersplash_jan_8130_2024_04_11_22_25_42.csv
# TERMINADO O ARQUIVO ride-rawdata/2024\download_supersoakersplash_mar_8130_2024_04_11_22_25_49.csv
# TERMINADO O ARQUIVO ride-rawdata/2024\download_tchibum_feb_8130_2024_04_11_22_25_58.csv
# TERMINADO O ARQUIVO ride-rawdata/2024\download_tchibum_jan_8130_2024_04_11_22_25_55.csv
# TERMINADO O ARQUIVO ride-rawdata/2024\download_tchibum_mar_8130_2024_04_11_22_26_01.csv
# TERMINADO O ARQUIVO ride-rawdata/2024\download_tigormountain_feb_8130_2024_04_11_22_26_10.csv
# TERMINADO O ARQUIVO ride-rawdata/2024\download_tigormountain_jan_8130_2024_04_11_22_26_07.csv
# TERMINADO O ARQUIVO ride-rawdata/2024\download_tigormountain_mar_8130_2024_04_11_22_26_13.csv
# TERMINADO O ARQUIVO ride-rawdata/2024\download_trenzinhovilaesperanca_feb_8130_2024_04_11_22_26_27.csv
# TERMINADO O ARQUIVO ride-rawdata/2024\download_trenzinhovilaesperanca_jan_8130_2024_04_11_22_26_19.csv
# TERMINADO O ARQUIVO ride-rawdata/2024\download_trenzinhovilaesperanca_mar_8130_2024_04_11_22_26_34.csv
# TERMINADO O ARQUIVO ride-rawdata/2024\download_xicarasmalucas_feb_8130_2024_04_11_22_26_42.csv
# TERMINADO O ARQUIVO ride-rawdata/2024\download_xicarasmalucas_jan_8130_2024_04_11_22_26_39.csv
# TERMINADO O ARQUIVO ride-rawdata/2024\download_xicarasmalucas_mar_8130_2024_04_11_22_26_46.csv
# TERMINADO O PROCESSAMENTO DE TODOS OS ARQUIVOS
